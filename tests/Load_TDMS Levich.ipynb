# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nptdms import TdmsFile
from pathlib import Path
import math
import pathlib
import os
# importing sys
import sys
nb_path = Path.cwd()

# %%
pack_path = nb_path.parent / "src" #/"arenz_group_python"
print(nb_path.parent)
print(pack_path)
print(f"path existits: {pack_path.exists()}")
# Out:
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\src
# path existits: True

# %%
#add
sys.path.insert(0,str(pack_path))
import arenz_group_python
print(arenz_group_python.__path__)
# Out:
# loading arenz_group_python
# ['c:\\Users\\gusta\\Documents\\GitHub\\Arenz_Group_Python\\src\\arenz_group_python']
# ['c:\\Users\\gusta\\Documents\\GitHub\\Arenz_Group_Python\\src\\arenz_group_python']

# %%
import arenz_group_python.data_treatment
print(arenz_group_python.data_treatment.__path__)
# Out:
# ['c:\\Users\\gusta\\Documents\\GitHub\\Arenz_Group_Python\\src\\arenz_group_python\\data_treatment']

# %%
from arenz_group_python.data_treatment.ec_data import EC_Data
from arenz_group_python import *
from arenz_group_python import EC_Data
from arenz_group_python import CV_Data
from arenz_group_python import CV_Datas

# %%
str_path = str(pack_path)
#sys.path.append("C:/Users/gustav.wiberg/Documents/GitHub/Python/Arenz_Group_Python/src/ArenzGroupPython")
print(str_path)
sys.path.append(str_path)
#import ec_data
#ec_data.reload()
# Out:
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\src

# %%
paths = []
path_to_dataSetFolder = nb_path / "data" / "set1"
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153559_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153541_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153333_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151300_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151725_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151512_ 3.tdms")

# %%
CVs = CV_Datas(paths)
for path in paths:
    cv = EC_Data(path)
    print(cv.setup)
    print(cv.rotation_unit)
for cv in CVs:
    print(cv.rotation)
# Out:
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.000 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.000 V', 'Rate': '0.500 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '13.2', 'Method.Cycle Duration': '4.4', 'Method.Avg.Time': '0.004', 'AC Frequency': '5.000E+3 Hz', 'AC Amplitude': '0.0050 V', 'RHE': '-0.938 V', 'Gas': 'O2', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '1600.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# /min
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.000 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.000 V', 'Rate': '0.250 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '26.4', 'Method.Cycle Duration': '8.8', 'Method.Avg.Time': '0.008', 'AC Frequency': '5.000E+3 Hz', 'AC Amplitude': '0.0050 V', 'RHE': '-0.938 V', 'Gas': 'O2', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '1600.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# /min
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.000 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.000 V', 'Rate': '0.050 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '132.0', 'Method.Cycle Duration': '44.0', 'Method.Avg.Time': '0.02', 'AC Frequency': '5.000E+3 Hz', 'AC Amplitude': '0.0050 V', 'RHE': '-0.938 V', 'Gas': 'O2', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '1600.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# /min
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.000 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.000 V', 'Rate': '0.050 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '132.0', 'Method.Cycle Duration': '44.0', 'Method.Avg.Time': '0.02', 'AC Frequency': '5.000E+3 Hz', 'AC Amplitude': '0.0050 V', 'RHE': '-0.938 V', 'Gas': 'O2', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '100.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# /min
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.000 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.000 V', 'Rate': '0.050 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '132.0', 'Method.Cycle Duration': '44.0', 'Method.Avg.Time': '0.02', 'AC Frequency': '5.000E+3 Hz', 'AC Amplitude': '0.0050 V', 'RHE': '-0.938 V', 'Gas': 'O2', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '900.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# /min
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.000 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.000 V', 'Rate': '0.050 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '132.0', 'Method.Cycle Duration': '44.0', 'Method.Avg.Time': '0.02', 'AC Frequency': '5.000E+3 Hz', 'AC Amplitude': '0.0050 V', 'RHE': '-0.938 V', 'Gas': 'O2', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '400.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# /min
# 1600.0
# 1600.0
# 1600.0
# 100.0
# 900.0
# 400.0

# %%
CVs.Levich(-0.5, "")
# Out:
# Levich -2.569606196443752e-05 -2.6788229678900968e-05
# (np.float64(-2.569606196443752e-05), np.float64(-2.6788229678900968e-05))

# %%
CVs.KouLev(-0.5, "")
# Out:
# KouLev -2.4525757101272656e-05 -2.568361941213339e-05
# (np.float64(-40773.46097291771), np.float64(-38935.32231394079))

# %%
fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(10)
plt.suptitle("Tafel Analysis")
CV_plot, Tafel_plot = fig.subplots(1,2)
CV_plot.title.set_text('CVs')

Tafel_plot.title.set_text('Tafel Plot')





path2 =[]
for x in path_to_dataSetFolder.iterdir():
        if x.is_file():

           path2.append(x)
        else:
            pass




CV_datas = [CV_Data() for i in range(len(paths))]
index=0
for path in paths:
    ec = EC_Data(path)
    cv= CV_Data()
    cv.conv(ec)
    #CV_datas.append(cv)
    CV_datas[index]=cv
    index=index+1 
print(index)

rot=[]
y = []
E = []
Epot=-0.5
y_axis_title =""
for cv in CV_datas:
    rot.append(math.sqrt(cv._rotation))
   
    cv.norm("area")
    cv.plot(plot = CV_plot, legend = cv._rotation)
    y.append(cv.get_i_at_E(Epot))
    E.append([Epot, Epot])
    y_axis_title= cv.i_label
    #print(cv.setup)
#print(rot)
rot = np.array(rot)
y = np.array(y)
CV_plot.plot(E,y, "o")
CV_plot.legend()
print(rot)
print(y[:,0])

Tafel_plot.plot(rot,y,'o')

Tafel_plot.set_xlabel("rotation$^{0.5}$")
Tafel_plot.set_ylabel(y_axis_title)
m, b = np.polyfit(rot, y[:,0], 1)
y_pos= m*rot+b
line,=Tafel_plot.plot(rot,y_pos,'-' )
line.set_label(f"pos: m={m:3.3e}")
m, b = np.polyfit(rot, y[:,1], 1)
y_neg= m*rot+b
line,=Tafel_plot.plot(rot,y_neg,'-' )
line.set_label(f"neg: m={m:3.3e}")
Tafel_plot.legend()
# Out:
# 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 42
#      40 y_axis_title =""
#      41 for cv in CV_datas:
# ---> 42     rot.append(math.sqrt(cv._rotation))
#      44     cv.norm("area")
#      45     cv.plot(plot = CV_plot, legend = cv._rotation)
#
# AttributeError: 'CV_Data' object has no attribute '_rotation'

# %%
fig = plt.figure()
fig.set_figheight(5)
fig.set_figwidth(10)
plt.suptitle("Tafel Analysis")
CV_plot, Tafel_plot = fig.subplots(1,2)
CV_plot.title.set_text('CVs')

Tafel_plot.title.set_text('Tafel Plot')





path2 =[]
for x in path_to_dataSetFolder.iterdir():
        if x.is_file():

           path2.append(x)
        else:
            pass




CV_datas = [CV_Data() for i in range(len(paths))]
index=0
for path in paths:
    ec = EC_Data(path)
    cv= CV_Data()
    cv.conv(ec)
    #CV_datas.append(cv)
    CV_datas[index]=cv
    index=index+1 
print(index)

rot=[]
y = []
E = []
Epot=-0.5
y_axis_title =""
for cv in CV_datas:
    rot.append(math.sqrt(cv._rotation))
   
    cv.norm("area")
    cv.plot(plot = CV_plot, legend = cv._rotation)
    y.append(cv.get_i_at_E(Epot))
    E.append([Epot, Epot])
    y_axis_title= cv.i_label
    #print(cv.setup)
#print(rot)
rot = np.array(rot)
y = np.array(y)
CV_plot.plot(E,y, "o")
CV_plot.legend()
print(rot)
print(y[:,0])

Tafel_plot.plot(rot,y,'o')

Tafel_plot.set_xlabel("rotation$^{0.5}$")
Tafel_plot.set_ylabel(y_axis_title)
m, b = np.polyfit(rot, y[:,0], 1)
y_pos= m*rot+b
line,=Tafel_plot.plot(rot,y_pos,'-' )
line.set_label(f"pos: m={m:3.3e}")
m, b = np.polyfit(rot, y[:,1], 1)
y_neg= m*rot+b
line,=Tafel_plot.plot(rot,y_neg,'-' )
line.set_label(f"neg: m={m:3.3e}")
Tafel_plot.legend()
