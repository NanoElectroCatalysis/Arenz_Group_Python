# %%
from pathlib import Path
import sys
nb_path = Path.cwd()
p = Path.cwd()
print(p)
for p in Path.cwd().parents:
    pa = p / "src"
    if pa.exists():
        print(pa)
        sys.path.insert(0,str(pa))
        break
print(pa)
#add
#sys.path.insert(0,str(pa))
import arenz_group_python
print(arenz_group_python.__path__)
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# loading arenz_group_python
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']

# %%
import matplotlib.pyplot as plt
#from scipy.signal import 
from arenz_group_python import EC_Data, EC_Datas
from arenz_group_python import CV_Datas, CV_Data
from pathlib import Path
import sys

# %%
#Find CV files to plot
files = list(Path().glob('CV*.tdms'))

#Load all data files
data = []
for path_to_file in files:
    data.append(EC_Data(path_to_file))

# %%
#Plot CV files
fig = plt.figure()
plt.suptitle("aa")
b = fig.subplots(1)
for x in data:
    x.plot("E","i", plot=b, y_smooth=40)

# %%
ecdatas = EC_Datas(files[0:1])

ecdatas.plot('E','i',y_smooth=20)
# Out:
# <Axes: xlabel='E / V', ylabel='i / A'>

# %%
b = EC_Data(files[2])
print(b.setup["Rate"])
# Out:
# 0.250 V/s

# %%
b = EC_Data(files[2])
b.plot_rawdata()
print(b.name)
print(b.rate + b.rate + b.rate, b.setup["Pressure"])
print(float(b.rate))


a = CV_Data(files[2])
print(a.setup)
print("Area", a.temp0)
print(a.rate,a.setup["Rate"],a.setup["Electrode.Area"],"AAAA", a.area )
#a.plot( )

qp,qn= a.integrate(-0.2,0.0,"all",True)
aa = a.weight
aa.value=10

print("Integration:",str(qp / a.area* a.area))
a.norm("area")
print("Integration_",a.integrate(-0.2,0.0,"all",True))
print(files[2])
a.name
# Out:
# CV_144857_ 3 : EC data sets:  2
# CV_144857_ 3
# 7.500e-01 V/s 100000 Pa
# 0.25
# CV 0.1 1.1 0.1
# {'Current Range': '1mA', 'Control Mode': 'WE', 'Cell Switch': 'TRUE', 'Start': '0.100 V', 'Start_Delay': '0.000 s', 'V1': '1.100 V', 'V2': '0.100 V', 'Rate': '0.250 V/s', 'Nr of Sweeps': '3.00', 'Method.Duration': '24.0', 'Method.Cycle Duration': '8.0', 'Method.Avg.Time': '0.008', 'AC Frequency': '0.000E+0 Hz', 'AC Amplitude': '0.0000 V', 'RHE': '-0.938 V', 'Gas': 'Ar', 'Temp_0': '298.15 K', 'Temp_1': '298.15 K', 'Pressure': '100000 Pa', 'Cell Material': 'Glass', 'CounterElectrode': 'Pt', 'Ref.Electrode': 'RHE', 'R.solution': '-1.00 Ohm', 'IR.compensation': '-1.00 Ohm', 'Electrolyte1': '0.1 M_HClO4: H2O_153', 'Electrolyte2': '_: _', 'Electrolyte3': '_: _', 'Electrode.Material': '', 'Electrode.Tip': '', 'Electrode.Area': '1.96E-5 m^2', 'Electrode.ExElectrode': '', 'Electrode.Cat.Loading': '0.00E+0 g m^-2', 'Electrode.Cat.Weight': '0.00E+0 g', 'Electrode.Cat.totWeight': '0.00E+0 g', 'Electrode.Cat.w%': '0.00', 'Electrode.Cat.Serial': '', 'Electrode.Cat.Batch': '', 'Electrode.Cat.Support': '', 'Electrode.Cat.Substrate': '', 'Note': '', 'Inst.Convection': 'NordEC - ECi-200 - RDE.lvlibp', 'Inst.Convection.Speed': '0.0 /min', 'Inst.Convection.1': '', 'Inst.Convection.1.Speed': '0.0 /min', 'Inst.Convection.2': '', 'Inst.Convection.2.Speed': '0.0 /min', 'Inst.SW0.Value': 'L', 'Inst.SW0.Driver': 'Switch DO - ECi-200', 'Application.Name': 'EC4 DAQ', 'Application.Version': '4.2.142.1', 'Lib.InterfacePotentiostat': '1.0.0.68', 'Lib.ECi-200': '1.1.43.0', 'Lib.Potentiostat_DAQ': '4.1.0.53', 'DAQ.Driver_Name': 'DAQmx', 'DAQ.Driver_Ver': '16.0.1', 'AddOn': '', 'DAQ.Device': 'USB-6361 (OEM)', 'DAQ.Device.ProductNum': '30107', 'DAQ.Device.SerialNum': '27578494', 'DAQ.Device.Name': 'Dev2', 'DAQ.AO.Channel': 'Dev2/ao0', 'DAQ.AO.Sampling': '100000 Hz;10000', 'DAQ.AI.Sampling': '30003 Hz;3000', 'Inst.Potentiostat': 'ECi-200', 'Inst.Potentiostat.Mode': 'WE'}
# Area 2.981e+02 K
# 2.500e-01 V/s 0.250 V/s 1.96E-5 m^2 AAAA 1.960e-05 m^2
# 2.012e-05 C
# Integration: 2.012e-05 C /m^2 m^2
# 1.027e+00 C m^2
# Integration_ [<arenz_group_python.data_treatment.util.Q_V object at 0x000002A9987C6B90>, <arenz_group_python.data_treatment.util.Q_V object at 0x000002A991DA4590>]
# CV_144857_ 3.tdms
# 'CV_144857_ 3'

# %%
a = "C /m^2 m^2.5"
b = a.split(" ", 100)
k={}
for c in b:
    aa = c.split("^",2)
    nyckel = aa[0]
    sign = 1
    fac =1
    if nyckel.startswith("/"):
        nyckel = nyckel[1:]
        sign = -1
    if len(aa)>1:
        fac = float(aa[1]) 
    val = float(k.get(nyckel, 0))  
    k[nyckel] = val + sign*fac
prep={} 
for key, value in k.items():
    if int(value*100) != 0:
        prep[key] = value
s =""
print (prep)  
for key, value in prep.items():
    s = s+ f' {key}^{value:.2f}'
print(s)
# Out:
# {'C': 1.0, 'm': 0.5}
#  C^1.00 m^0.50

# %%
file_num=11
print(files[file_num])
b = EC_Data(files[file_num])
b.plot_rawdata()
#c= CV_Data(files[file_num], sgfg="bf")
a = CV_Data()
a.conv(b)
a.plot()

print("Integration_",a.integrate(-0.2,0))
# Out:
# CV_152635_ 3.tdms
# CV_152635_ 3 : EC data sets:  4
# CV 0.0 1.1 0.0
# -3.004e-03 C
# Integration_ [<arenz_group_python.data_treatment.util.Q_V object at 0x000002A9962F0050>, <arenz_group_python.data_treatment.util.Q_V object at 0x000002A9968E8590>]
# ['C', '/m^2', 'm^2']

# %%
cv = CV_Datas(files[11:13])
cv.plot()
# Out:
# CV 0.0 1.1 0.0
# CV 0.0 1.1 0.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 cv = CV_Datas(files[11:13])
# ----> 2 cv.plot()
#
# File c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_datas.py:90, in CV_Datas.plot(self, *args, **kwargs)
#      88 #cv_kwargs["legend"] = "aaaaa"
#      89 cv_kwargs["plot"] = CV_plot
# ---> 90 cv_kwargs["name"] = self.setup_data.name
#      91 cv.plot(**cv_kwargs)
#      92 y_axis_title= cv.i_label
#
# AttributeError: 'CV_Datas' object has no attribute 'setup_data'
