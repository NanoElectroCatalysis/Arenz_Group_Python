# %%
import matplotlib.pyplot as plt
#from scipy.signal import 
from arenz_group_python import EC_Data
from pathlib import Path
import sys
# Out:
# loading arenz_group_python
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\.conda\\Lib\\site-packages\\arenz_group_python\\contents']
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
#       2 #from scipy.signal import
# ----> 3 from arenz_group_python import EC_Data
#       4 from pathlib import Path
#       5 import sys
#
# ImportError: cannot import name 'EC_Data' from 'arenz_group_python' (c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\.conda\Lib\site-packages\arenz_group_python\__init__.py)

# %%
#Find CV files to plot
files = list(Path().glob('CV*.tdms'))

#Load all data files
data = []
for path_to_file in files:
    data.append(EC_Data(path_to_file))

# %%
#Plot CV files
fig = plt.figure()
plt.suptitle("aa")
b = fig.subplots(1)
for x in data:
    x.plot("E","i", plot=b, y_smooth=40)
