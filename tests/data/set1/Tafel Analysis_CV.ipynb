# %%
from pathlib import Path
import sys
nb_path = Path.cwd()
p = Path.cwd()
print(p)
for p in Path.cwd().parents:
    pa = p / "src"
    if pa.exists():
        print(pa)
        sys.path.insert(0,str(pa))
        break
print(pa)
#add
#sys.path.insert(0,str(pa))
import arenz_group_python
print(arenz_group_python.__path__)


from arenz_group_python import CV_Datas
from arenz_group_python import Project_Paths
print(nb_path)
pp= Project_Paths()
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# loading arenz_group_python
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1

# %%
from pathlib import Path
import arenz_group_python
from arenz_group_python import CV_Datas
from arenz_group_python import CV_Data
from arenz_group_python import EC_Data

print(arenz_group_python.__path__)
nb_path = Path.cwd()
# Out:
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']

# %%
pack_path = nb_path.parent / "src" #/"arenz_group_python"
print(nb_path.parent)
print(pack_path)
print(f"path existits: {pack_path.exists()}")
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\src
# path existits: False

# %%
paths = []
path_to_dataSetFolder = nb_path
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153559_ 3.tdms")
#paths.append( path_to_dataSetFolder / "CV_153541_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153333_ 3.tdms")
#paths.append( path_to_dataSetFolder / "CV_151300_ 3.tdms")
#paths.append( path_to_dataSetFolder / "CV_151725_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151512_ 3.tdms")

bg_path = path_to_dataSetFolder / "CV_144913_ 3.tdms"
bg_cv = CV_Data(bg_path,y_smooth = 10)
#bg_cv.conv(EC_Data(bg_path),y_smooth = 4) 
p= bg_cv.plot()

# %%
CVs = CV_Datas(paths, y_smooth=0)
for cv in CVs:
    print(cv.area)
#CVs.bg_corr(bg_cv)
#CVs.plot(legend="name", dir="pos")
Tafel_pos, Tafel_neg = CVs.Tafel([-0.15,-.05],-.2, "area_cm", dir="all" )

for a in Tafel_pos:
    print(a)
# Out:
# 1.960e-05 m^2
# 1.960e-05 m^2
# 1.960e-05 m^2
# Tafel -0.05905257598228698 V/dec
# Tafel -0.057946541152634555 V/dec
# Tafel -0.05370347692192041 V/dec
# -5.905e-02 V/dec
# -5.795e-02 V/dec
# -5.370e-02 V/dec
