# %%
from pathlib import Path
import sys
nb_path = Path.cwd()
p = Path.cwd()
print(p)
for p in Path.cwd().parents:
    pa = p / "src"
    if pa.exists():
        print(pa)
        sys.path.insert(0,str(pa))
        break
print(pa)
#add
#sys.path.insert(0,str(pa))
import arenz_group_python
print(arenz_group_python.__path__)
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# loading arenz_group_python
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']

# %%
import matplotlib.pyplot as plt
#import arenz_group_python
from arenz_group_python import EC_Data
from arenz_group_python import EC_Datas
from pathlib import Path
import sys

# %%
#Find CV files to plot
files = list(Path().glob('Steps*.tdms'))

#Load all data files
data = [EC_Data() for _ in range(len(files))]
#data = []
i=0
for path_to_file in files:
    #data.append(EC_Data(path_to_file))
    data[i] = EC_Data(path_to_file)
    i=i+1

# %%
datas = EC_Datas(files)
datas.plot("E","j", limit_min = 10)

i=0
print(len(datas[0].Time))
for t in datas[0].Time:
    if t>=10 : 
        print(t)
        break
    i=i+1
print(datas[0].index_at_time(50))
print(i)
# Out:
# 1000
# 10.09899
# 501
# 101

# %%
#Plot CV files
fig = plt.figure()
plt.suptitle("Steps")
b = fig.subplots(3,1)
b[0]
for x in data:
    x.plot("Time","E", plot=b[0])
    x.plot("Time","i", plot=b[1])
    x.plot("E","i", plot=b[2])

# %%
#Find CV files to plot
files2 = list(Path(".").glob('CV*.tdms'))
print(files2)
from arenz_group_python import CV_Data
#Load all data files
data = []
for path_to_file in files2:
    data.append(CV_Data(path_to_file))
    
data[0].plot()
# Out:
# [WindowsPath('CV_144700_ 3.tdms'), WindowsPath('CV_144820_ 3.tdms'), WindowsPath('CV_144857_ 3.tdms'), WindowsPath('CV_144913_ 3.tdms'), WindowsPath('CV_151047_ 3.tdms'), WindowsPath('CV_151300_ 3.tdms'), WindowsPath('CV_151512_ 3.tdms'), WindowsPath('CV_151725_ 3.tdms'), WindowsPath('CV_151938_ 3.tdms'), WindowsPath('CV_152150_ 3.tdms'), WindowsPath('CV_152403_ 3.tdms'), WindowsPath('CV_152635_ 3.tdms'), WindowsPath('CV_153036_ 3.tdms'), WindowsPath('CV_153333_ 3.tdms'), WindowsPath('CV_153501_ 3.tdms'), WindowsPath('CV_153541_ 3.tdms'), WindowsPath('CV_153559_ 3.tdms')]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       6 data = []
#       7 for path_to_file in files2:
# ----> 8     data.append(CV_Data(path_to_file))
#      10 data[0].plot()
#
# File c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_data.py:46, in CV_Data.__init__(self, *args, **kwargs)
#      43     return
#      44 else:
#      45     #print(kwargs)
# ---> 46     self.conv(EC_Data(args[0]),**kwargs)
#
# File c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_data.py:101, in CV_Data.conv(self, data, **kwargs)
#      95 """Converts EC_Data to a CV
#      96
#      97 Args:
#      98     data (EC_Data): the data that should be converted.
#      99 """
#     100 #print("Convert:",kwargs)
# --> 101 self.convert(data.Time,data.E,data.i,**kwargs)
#     102 self.setup_data = data.setup_data
#     103 #self.setup = data.setup
#     104 #self.set_area(data._area, data._area_unit)
#     105 #self.set_rotation(data.rotation, data.rotation_unit)
#     106 #self.name = data.name
#
# File c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_data.py:175, in CV_Data.convert(self, time, E, i, **kwargs)
#     172 x_n = np.flipud(x[zero_crossings[0]:])
#     173 y_n = np.flipud(y[zero_crossings[0]:])
# --> 175 y_pos=np.interp(x_sweep, x_u, y_u)
#     176 y_neg=np.interp(x_sweep, x_n, y_n)
#     178 for i in range(1,y_pos.size):
#
# File c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\.conda\Lib\site-packages\numpy\lib\_function_base_impl.py:1599, in interp(x, xp, fp, left, right, period)
#    1596     xp = np.concatenate((xp[-1:]-period, xp, xp[0:1]+period))
#    1597     fp = np.concatenate((fp[-1:], fp, fp[0:1]))
# -> 1599 return interp_func(x, xp, fp, left, right)
#
# ValueError: array of sample points is empty
