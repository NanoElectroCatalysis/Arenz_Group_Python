# %% [markdown]
# # Levich and Koutechy-Levich analysis notebook for CV data.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
import sys
nb_path = Path.cwd()
p = Path.cwd()
print(p)
for p in Path.cwd().parents:
    pa = p / "src"
    if pa.exists():
        print(pa)
        sys.path.insert(0,str(pa))
        break
print(pa)
#add
#sys.path.insert(0,str(pa))
import arenz_group_python
print(arenz_group_python.__path__)


from arenz_group_python import CV_Datas, Quanity_Value_Unit as QV
from arenz_group_python import Project_Paths
print(nb_path)
pp= Project_Paths()
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# loading arenz_group_python
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = nb_path
print (pp.cwd)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153559_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153541_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153333_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151300_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151725_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151512_ 3.tdms")
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1

# %% [markdown]
# ## 3. Load in the data files

# %%
CVs = CV_Datas(paths)
for cv in CVs:
    #cv.set_area(0.04532, "cm^2")
    print("aa", cv.area)
# Out:
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2
# aa 1.960e-05 m^2

# %%
a =QV("4 aa ba")
b =QV("1 aa ba")
print(a.unit)
print(b*5)
print(b**5)
# Out:
# aa ba
# 5.000e+00 aa ba
# 1.000e+00 aa^5 ba^5

# %%
#plot = CVs.plot("" ,legend = "name", smooth_y=50)
CVs[1].plot(title = "aa")
for cv in CVs[:1]:
    print(cv.rate)
    cv2 = cv * (1 / 1000.)
    #cv2.plot()

#CVs.bg_corr(CVs)
CVs.plot()
bg_corr = CVs.bg_corr(path_to_dataSetFolder / "CV_144913_ 3.tdms" )

#bg_corr.plot()
# Out:
# 5.000e-01 V/s

# %% [markdown]
# ## 4. Levich analysis

# %%
slope1, slope2 = CVs.Levich(-0.5,"area_cm", y_smooth = 11, )
#use the argument to normalize the data
# Out:
# Levich analysis
# dir 	pos      	neg
#  :     	A cm^-2 / rpm^0.5 	A cm^-2 / rpm^0.5
# slope: 	-1.31e-04 	-1.37e-04

# %% [markdown]
# ## 5. Koutechy-Levich analysis

# %%
slope1, slope2 = CVs.KouLev(-0.5,"area", y_smooth = 5)
print(slope1 ** 1, slope1 ** -1)
#use the argument to normalize the data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 slope1, slope2 = CVs.KouLev(-0.5,"area", y_smooth = 5)
#       2 print(slope1 ** 1, slope1 ** -1)
#       3 #use the argument to normalize the data
#
# File c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_datas.py:298, in CV_Datas.KouLev(self, Epot, *args, **kwargs)
#     295 #CV_plot.plot(E,y_values[:,0], STYLE_POS_DL, E,y_values[:,1],STYLE_NEG_DL)
#     296 #CV_plot.legend()
#     297 cv_kwargs = kwargs
# --> 298 rot,y,E,y_axis_title,y_axis_unit  = plots_for_rotations(self.datas,Epot,*args, **cv_kwargs)
#     300 #rot = np.array(rot)
#     302 rot = 1 / rot
#
# File c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_datas.py:480, in plots_for_rotations(datas, Epot, *args, **kwargs)
#     478 rot = np.array(rot)
#     479 y = np.array(y)
# --> 480 CV_plot =  cv_kwargs["plot"]
#     481 CV_plot.plot(E,y[:,0], STYLE_POS_DL,E,y[:,1], STYLE_NEG_DL)
#     482 CV_plot.legend()
#
# KeyError: 'plot'
