# %% [markdown]
# # Levich and Koutechy-Levich analysis notebook for CV data.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
import sys
nb_path = Path.cwd()
p = Path.cwd()
print(p)
for p in Path.cwd().parents:
    pa = p / "src"
    if pa.exists():
        print(pa)
        sys.path.insert(0,str(pa))
        break
print(pa)
#add
#sys.path.insert(0,str(pa))
import arenz_group_python
print(arenz_group_python.__path__)


from arenz_group_python import CV_Datas
print(nb_path)
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src
# loading arenz_group_python
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\src\\arenz_group_python']
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\tests\data\set1

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = nb_path
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153559_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153541_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_153333_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151300_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151725_ 3.tdms")
paths.append( path_to_dataSetFolder / "CV_151512_ 3.tdms")

# %% [markdown]
# ## 3. Load in the data files

# %%
CVs = CV_Datas(paths)

# %% [markdown]
# ## 4. Levich analysis

# %%
CVs.Levich(-0.5, y_smooth = 11)
#use the argument to normalize the data
# Out:
# Levich -2.569606196443752e-05 -2.678822967890097e-05
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_datas.py:96: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   CV_plot.legend()
# (np.float64(-2.569606196443752e-05), np.float64(-2.678822967890097e-05))

# %% [markdown]
# ## 5. Koutechy-Levich analysis

# %%
CVs.KouLev(-0.5, y_smooth = 5)
#use the argument to normalize the data
# Out:
# KouLev -2.4525757101272656e-05 -2.568361941213339e-05
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\src\arenz_group_python\data_treatment\cv_datas.py:149: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   CV_plot.legend()
# (np.float64(-40773.46097291771), np.float64(-38935.32231394079))
