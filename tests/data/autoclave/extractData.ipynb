# %%
from pathlib import Path
import sys
p = Path.cwd()
print(p)
for p in Path.cwd().parents:
    pa = p / "src"
    if pa.exists():
        print(pa)
        sys.path.insert(0,str(pa))
        break
print(pa)
#add
#sys.path.insert(0,str(pa))
import arenz_group_python
print(arenz_group_python.__path__)
# Out:
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\tests\data\autoclave
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\src
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\src
# loading arenz_group_python
# ['c:\\Users\\gusta\\Documents\\GitHub\\Arenz_Group_Python\\src\\arenz_group_python']
# ['c:\\Users\\gusta\\Documents\\GitHub\\Arenz_Group_Python\\src\\arenz_group_python']

# %%
from arenz_group_python import AutoClaveSynthesis

# %%
#from arenz_group_python import AutoClaveSynthesis

c = AutoClaveSynthesis("ATS-JF009#01.tdms")
a,b = c.plot("Time_in_min", "T_Reactor_in_C", y_median=5)
a,b = c.plot("Time_in_min", "T_Reactor_in_C", y_median=7)

#a,b = c.plot("Time", "T_Reactor")

# %%
c.AC_synthesis(temp_median=5, temp_smooth = 10)
a,b = c.plot("Time_in_min", "T_Reactor_in_C",)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 c.AC_synthesis(temp_median=5, temp_smooth = 10)
#       2 a,b = c.plot("Time_in_min", "T_Reactor_in_C",)
#
# File c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\src\arenz_group_python\data_treatment\autoclave_synthesis.py:221, in AutoClaveSynthesis.AC_synthesis(self, **kwargs)
#     217 parameters_df = pd.DataFrame(list(parameters.items()), columns=['Parameter', 'Value'])
#     218 parameters_df['Value'] = parameters_df['Value'].astype(float)
# --> 221 tb = {
#     222     {"Set Temperature", set_temperature, T_unit},
#     223     {'Max Temperature of Reactor',round(max_temperature_R, 2), T_unit},
#     224     {'Time to Set Temperature', round(time_set_temp, 2), time_unit},
# ...
