# %% [markdown]
# # CV_153501_ 3.tdms

# %%
from arenz_group_python import CV_Data, EC_Data
from pathlib import Path
import csv
nb_path = Path.cwd()

raw_data_path = nb_path.parent / "rawdata"  
data_path =  nb_path.parent / "data" / "extracted3.csv"
data_path2 =  nb_path.parent / "data" / "extracted_2.csv"

file_path =  raw_data_path / "CV_153541_ 3.tdms"
#C:\Users\gusta\Documents\GitHub\Arenz_Group_Python\tests\Packages\rawdata\CV_153541_ 3.tdms
print(str(nb_path))
print(file_path)
# Out:
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\tests\Packages\notebooks_exploration_cleaning
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\tests\Packages\rawdata\CV_153541_ 3.tdms

# %%
sample_name = "sample10"
prop1 = 4.366
prop2 = 32382

# %%
cv = CV_Data(file_path)
cv.plot()

activity = cv.get_i_at_E(-0.4)

# %%
#with open(data_path, 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter='\t',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    spamwriter.writerow([sample_name, prop1, prop2]  + activity) #row
    spamwriter.writerow([sample_name, prop1, prop2]  + activity) #row
# Out:
#   Cell In[15], line 2
#     spamwriter = csv.writer(csvfile, delimiter='\t',
#     ^
# IndentationError: unexpected indent

# %%
from arenz_group_python import save_key_values
#print(str(data_path.exists))
save_key_values(data_path, sample_name, [prop1, prop2]  + activity)
print(data_path)
# Out:
# sample name found -  updating row
# c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\tests\Packages\data\extracted3.csv

# %%
#with open(data_path, 'r', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter='\t', quotechar='|')

    all_data =[]
    i=0
    for row in spamreader:
        all_data.append(row)
        if(row[0] == sample_name):
            print("name found -  updating row")
            all_data[i] = [sample_name, prop1, prop2]  + activity
        print(row[0])
        print(', '.join(row))
        i+=1

print(all_data)

#with open(data_path2, 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter='\t',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for row in all_data:
        spamwriter.writerow(row) #row
# Out:
#   Cell In[18], line 2
#     spamreader = csv.reader(csvfile, delimiter='\t', quotechar='|')
#     ^
# IndentationError: unexpected indent
