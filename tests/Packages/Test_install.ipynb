# %% [markdown]
# General installation from github
# pip install "Package" @ git+"URL of the repository#subdirectory=path"

# %%
import sys

# %%
# !{sys.executable} -m pip install arenz_group_python@git+https://github.com/Guswib/Arenz_Group_Python
# Out:
# Collecting arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python
#   Cloning https://github.com/Guswib/Arenz_Group_Python to c:\users\gustav.wiberg\appdata\local\temp\pip-install-r2nmik0r\arenz-group-python_e18f6e933b1b4c42b927fb4920cc6ab1
#   Resolved https://github.com/Guswib/Arenz_Group_Python to commit 99e9ff0ab5befc81f8e79b2f1ebfa11ae68125c3
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nptdms (from arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading npTDMS-1.9.0.tar.gz (180 kB)
#      ---------------------------------------- 0.0/180.6 kB ? eta -:--:--
#      ------------------------------------- 180.6/180.6 kB 10.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting matplotlib (from arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading matplotlib-3.9.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting pathlib (from arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading fonttools-4.53.0-cp311-cp311-win_amd64.whl.metadata (165 kB)
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------------------------------- 165.5/165.5 kB 9.7 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting numpy>=1.23 (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading numpy-2.0.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.venv\lib\site-packages (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python) (24.1)
# Collecting pillow>=8 (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.venv\lib\site-packages (from matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->arenz_group_python@ git+https://github.com/Guswib/Arenz_Group_Python) (1.16.0)
# Downloading matplotlib-3.9.1-cp311-cp311-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/8.0 MB 12.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.1/8.0 MB 11.8 MB/s eta 0:00:01
#    -------- ------------------------------- 1.7/8.0 MB 11.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.2/8.0 MB 11.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.0 MB 11.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.3/8.0 MB 11.6 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.0 MB 12.2 MB/s eta 0:00:01
#    --------------------- ------------------ 4.4/8.0 MB 12.1 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.0 MB 12.0 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/8.0 MB 12.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.0 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 6.5/8.0 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.0/8.0 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 11.3 MB/s eta 0:00:00
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
#    ---------------------------------------- 0.0/188.2 kB ? eta -:--:--
#    --------------------------------------- 188.2/188.2 kB 11.1 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 10.9 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.2 MB 11.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 10.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Downloading numpy-2.0.0-cp311-cp311-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.6/16.5 MB 13.1 MB/s eta 0:00:02
#    -- ------------------------------------- 1.2/16.5 MB 12.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.7/16.5 MB 12.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.2/16.5 MB 11.9 MB/s eta 0:00:02
#    ------ --------------------------------- 2.8/16.5 MB 11.9 MB/s eta 0:00:02
#    -------- ------------------------------- 3.3/16.5 MB 11.8 MB/s eta 0:00:02
#    --------- ------------------------------ 3.9/16.5 MB 11.7 MB/s eta 0:00:02
#    --------- ------------------------------ 3.9/16.5 MB 10.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.8/16.5 MB 11.4 MB/s eta 0:00:02
#    ------------- -------------------------- 5.5/16.5 MB 12.1 MB/s eta 0:00:01
#    -------------- ------------------------- 6.0/16.5 MB 12.0 MB/s eta 0:00:01
#    --------------- ------------------------ 6.5/16.5 MB 11.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 7.1/16.5 MB 11.9 MB/s eta 0:00:01
#    ------------------ --------------------- 7.6/16.5 MB 11.9 MB/s eta 0:00:01
#    ------------------- -------------------- 8.2/16.5 MB 11.9 MB/s eta 0:00:01
#    --------------------- ------------------ 8.7/16.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.2/16.5 MB 11.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.8/16.5 MB 11.8 MB/s eta 0:00:01
#    ------------------------- -------------- 10.3/16.5 MB 11.7 MB/s eta 0:00:01
#    -------------------------- ------------- 10.9/16.5 MB 11.7 MB/s eta 0:00:01
#    --------------------------- ------------ 11.4/16.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.6/16.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.6/16.5 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.1/16.5 MB 10.9 MB/s eta 0:00:01
#    ------------------------------ --------- 12.8/16.5 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.1/16.5 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.6/16.5 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 15.2/16.5 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 15.7/16.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  16.2/16.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  16.5/16.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 11.3 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.6 MB 10.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.6 MB 13.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 12.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.6 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------  2.5/2.6 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 11.6 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Building wheels for collected packages: arenz_group_python, nptdms
#   Building wheel for arenz_group_python (pyproject.toml): started
#   Building wheel for arenz_group_python (pyproject.toml): finished with status 'done'
#   Created wheel for arenz_group_python: filename=Arenz_Group_Python-0.0.1-py3-none-any.whl size=4617 sha256=4595604e1eaa1ea63f8e6286f8c9dc5c5d088779c43ef50a5be09c863a3e13af
#   Stored in directory: C:\Users\gustav.wiberg\AppData\Local\Temp\pip-ephem-wheel-cache-bp2f6moq\wheels\e7\50\a9\3224467eb40352eec80bb2ec0ca2b0ceabb74154f19cf4d783
#   Building wheel for nptdms (pyproject.toml): started
#   Building wheel for nptdms (pyproject.toml): finished with status 'done'
#   Created wheel for nptdms: filename=npTDMS-1.9.0-py3-none-any.whl size=107843 sha256=21990fdc89efe58ad9bc57873a5049c3ea9e069a56416533dbbee3103f5d33e5
#   Stored in directory: c:\users\gustav.wiberg\appdata\local\pip\cache\wheels\27\8e\a7\be537457401c9317f456a4834da804161a190eacd286c1a116
# Successfully built arenz_group_python nptdms
# Installing collected packages: pathlib, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, nptdms, contourpy, matplotlib, arenz_group_python
# Successfully installed arenz_group_python-0.0.1 contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 kiwisolver-1.4.5 matplotlib-3.9.1 nptdms-1.9.0 numpy-2.0.0 pathlib-1.0.1 pillow-10.4.0 pyparsing-3.1.2
#   Running command git clone --filter=blob:none --quiet https://github.com/Guswib/Arenz_Group_Python 'C:\Users\gustav.wiberg\AppData\Local\Temp\pip-install-r2nmik0r\arenz-group-python_e18f6e933b1b4c42b927fb4920cc6ab1'

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with version '2.6.0', sqlite_version '3.42.0'
# loading arenz_group_python
# ['c:\\Users\\gustav.wiberg\\Documents\\GitHub\\Python\\Arenz_Group_Python\\.venv\\Lib\\site-packages\\arenz_group_python\\contents']
# c:\Users\gustav.wiberg\Documents\GitHub\Python\Arenz_Group_Python\.venv\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# IPython             asyncore            matplotlib          sunau
# PIL                 atexit              matplotlib_inline   symtable
# __future__          audioop             mimetypes           sys
# __hello__           base64              mmap                sysconfig
# __phello__          bdb                 mmapfile            tabnanny
# _abc                binascii            mmsystem            tarfile
# _aix_support        bisect              modulefinder        telnetlib
# _ast                builtins            mpl_toolkits        tempfile
# _asyncio            bz2                 msilib              test
# _bisect             cProfile            msvcrt              textwrap
# _blake2             calendar            multiprocessing     this
# _bootsubprocess     cgi                 nest_asyncio        threading
# _bz2                cgitb               netbios             time
# _codecs             chunk               netrc               timeit
# _codecs_cn          cmath               nntplib             timer
# _codecs_hk          cmd                 nptdms              tkinter
# _codecs_iso2022     code                nt                  token
# _codecs_jp          codecs              ntpath              tokenize
# _codecs_kr          codeop              ntsecuritycon       tomllib
# _codecs_tw          collections         nturl2path          tornado
# _collections        colorama            numbers             trace
# _collections_abc    colorsys            numpy               traceback
# _compat_pickle      comm                odbc                tracemalloc
# _compression        commctrl            opcode              traitlets
# _contextvars        compileall          operator            tty
# _csv                concurrent          optparse            turtle
# _ctypes             configparser        os                  turtledemo
# _ctypes_test        contextlib          packaging           types
# _datetime           contextvars         parso               typing
# _decimal            contourpy           pathlib             typing_extensions
# _distutils_hack     copy                pdb                 unicodedata
# _elementtree        copyreg             perfmon             unittest
# _functools          crypt               pickle              urllib
# _hashlib            csv                 pickletools         uu
# _heapq              ctypes              pip                 uuid
# _imp                curses              pipes               venv
# _io                 cycler              pkg_resources       warnings
# _json               dataclasses         pkgutil             wave
# _locale             datetime            platform            wcwidth
# _lsprof             dateutil            platformdirs        weakref
# _lzma               dbi                 plistlib            webbrowser
# _markupbase         dbm                 poplib              win2kras
# _md5                dde                 posixpath           win32api
# _msi                debugpy             pprint              win32clipboard
# _multibytecodec     decimal             profile             win32com
# _multiprocessing    decorator           prompt_toolkit      win32con
# _opcode             difflib             pstats              win32console
# _operator           dis                 psutil              win32cred
# _osx_support        distutils           pty                 win32crypt
# _overlapped         doctest             pure_eval           win32cryptcon
# _pickle             email               py_compile          win32event
# _py_abc             encodings           pyclbr              win32evtlog
# _pydecimal          ensurepip           pydoc               win32evtlogutil
# _pyio               enum                pydoc_data          win32file
# _queue              errno               pyexpat             win32gui
# _random             executing           pygments            win32gui_struct
# _sha1               faulthandler        pylab               win32help
# _sha256             filecmp             pyparsing           win32inet
# _sha3               fileinput           pythoncom           win32inetcon
# _sha512             fnmatch             pywin               win32job
# _signal             fontTools           pywin32_bootstrap   win32lz
# _sitebuiltins       fractions           pywin32_testutil    win32net
# _socket             ftplib              pywintypes          win32netcon
# _sqlite3            functools           queue               win32pdh
# _sre                gc                  quopri              win32pdhquery
# _ssl                genericpath         random              win32pdhutil
# _stat               getopt              rasutil             win32pipe
# _statistics         getpass             re                  win32print
# _string             gettext             regcheck            win32process
# _strptime           glob                regutil             win32profile
# _struct             graphlib            reprlib             win32ras
# _symtable           gzip                rlcompleter         win32rcparser
# _testbuffer         hashlib             runpy               win32security
# _testcapi           heapq               sched               win32service
# _testconsole        hmac                secrets             win32serviceutil
# _testimportmultiple html                select              win32timezone
# _testinternalcapi   http                selectors           win32trace
# _testmultiphase     idlelib             servicemanager      win32traceutil
# _thread             imaplib             setuptools          win32transaction
# _threading_local    imghdr              shelve              win32ts
# _tkinter            imp                 shlex               win32ui
# _tokenize           importlib           shutil              win32uiole
# _tracemalloc        inspect             signal              win32verstamp
# _typing             io                  site                win32wnet
# _uuid               ipaddress           six                 winerror
# _warnings           ipykernel           smtpd               winioctlcon
# _weakref            ipykernel_launcher  smtplib             winnt
# _weakrefset         isapi               sndhdr              winperf
# _win32sysloader     itertools           socket              winreg
# _winapi             jedi                socketserver        winsound
# _winxptheme         json                sqlite3             winxpgui
# _xxsubinterpreters  jupyter             sre_compile         winxptheme
# _zoneinfo           jupyter_client      sre_constants       wsgiref
# abc                 jupyter_core        sre_parse           xdrlib
# adodbapi            keyword             ssl                 xml
# afxres              kiwisolver          sspi                xmlrpc
# aifc                lib2to3             sspicon             xxsubtype
# antigravity         linecache           stack_data          zipapp
# arenz_group_python  locale              start_pythonwin     zipfile
# argparse            logging             stat                zipimport
# array               lzma                statistics          zlib
# ast                 mailbox             string              zmq
# asttokens           mailcap             stringprep          zoneinfo
# asynchat            marshal             struct
# asyncio             math                subprocess
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
