# %% [markdown]
# Run this notebook to install most common packages to a python kernal.
#
# Start by placing this file in the root of a project.
# If you are using vscode, create a new venv, before starting.

# %%
import sys

# %%
#req_packages = ["pandas","numpy","nptdms","matplotlib","pathlib"]

# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install nptdms
# !{sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install pathlib
# !{sys.executable} -m pip install scipy
# Out:
# Requirement already satisfied: numpy in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (2.0.0)
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.6 MB 4.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.6/11.6 MB 6.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.6 MB 7.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.6 MB 8.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.6 MB 9.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/11.6 MB 9.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.1/11.6 MB 9.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.7/11.6 MB 10.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.2/11.6 MB 10.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.6 MB 10.4 MB/s eta 0:00:01
#    ------------------ --------------------- 5.3/11.6 MB 10.5 MB/s eta 0:00:01
#    ------------------- -------------------- 5.8/11.6 MB 10.6 MB/s eta 0:00:01
#    --------------------- ------------------ 6.4/11.6 MB 10.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.9/11.6 MB 10.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.4/11.6 MB 10.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.0/11.6 MB 10.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.6 MB 10.9 MB/s eta 0:00:01
#    ------------------------------- -------- 9.0/11.6 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 9.6/11.6 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.1/11.6 MB 11.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.7/11.6 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 11.2/11.6 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 11.5 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    ------------------------------------- - 481.3/505.5 kB 14.7 MB/s eta 0:00:01
#    --------------------------------------- 505.5/505.5 kB 10.5 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Requirement already satisfied: nptdms in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (1.9.0)
# Requirement already satisfied: numpy in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from nptdms) (2.0.0)
# Requirement already satisfied: matplotlib in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pathlib in c:\users\gustav.wiberg\documents\github\python\arenz_group_python\.conda\lib\site-packages (1.0.1)
# Collecting scipy
#   Downloading scipy-1.14.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60
7 MB/s eta 0:00:02
#    ---------------------- ----------------- 24.8/44.7 MB 11.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 25.9/44.7 MB 11.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.6/44.7 MB 11.9 MB/s eta 0:00:02
#    ------------------------ --------------- 27.1/44.7 MB 11.9 MB/s eta 0:00:02
#    ------------------------ --------------- 27.6/44.7 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 28.2/44.7 MB 11.7 MB/s eta 0:00:02
#    ------------------------- -------------- 28.7/44.7 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 29.2/44.7 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 29.8/44.7 MB 11.9 MB/s eta 0:00:02
#    --------------------------- ------------ 30.3/44.7 MB 11.9 MB/s eta 0:00:02
#    --------------------------- ------------ 30.8/44.7 MB 11.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.4/44.7 MB 11.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.9/44.7 MB 11.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.5/44.7 MB 11.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.0/44.7 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 33.5/44.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 34.1/44.7 MB 13.4 MB/s eta 0:00:01
#    ------------------------------ --------- 34.6/44.7 MB 12.9 MB/s eta 0:00:01
#    ------------------------------- -------- 35.2/44.7 MB 12.6 MB/s eta 0:00:01
#    ------------------------------- -------- 35.7/44.7 MB 12.3 MB/s eta 0:00:01
#    -------------------------------- ------- 36.2/44.7 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 36.8/44.7 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 37.3/44.7 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 37.9/44.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.4/44.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.9/44.7 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.4/44.7 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.0/44.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 40.5/44.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 41.1/44.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 41.6/44.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------- -- 42.1/44.7 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 42.7/44.7 MB 11.9 MB/s eta 0:00:01
#    -------------------------------------- - 43.2/44.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  43.6/44.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.7 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 44.7/44.7 MB 10.2 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.14.0

# %% [markdown]
# Check which modules that are installed:

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             atexit              matplotlib_inline   subprocess
# PIL                 audioop             mimetypes           sunau
# __future__          base64              mmap                symtable
# __hello__           bdb                 mmapfile            sys
# __phello__          binascii            mmsystem            sysconfig
# _abc                bisect              modulefinder        tabnanny
# _aix_support        builtins            mpl_toolkits        tarfile
# _ast                bz2                 msilib              telnetlib
# _asyncio            cProfile            msvcrt              tempfile
# _bisect             calendar            multiprocessing     test
# _blake2             cgi                 nest_asyncio        textwrap
# _bootsubprocess     cgitb               netbios             this
# _bz2                chunk               netrc               threading
# _codecs             cmath               nntplib             time
# _codecs_cn          cmd                 nptdms              timeit
# _codecs_hk          code                nt                  timer
# _codecs_iso2022     codecs              ntpath              tkinter
# _codecs_jp          codeop              ntsecuritycon       token
# _codecs_kr          collections         nturl2path          tokenize
# _codecs_tw          colorama            numbers             tomllib
# _collections        colorsys            numpy               tornado
# _collections_abc    comm                odbc                trace
# _compat_pickle      commctrl            opcode              traceback
# _compression        compileall          operator            tracemalloc
# _contextvars        concurrent          optparse            traitlets
# _csv                configparser        os                  tty
# _ctypes             contextlib          packaging           turtle
# _ctypes_test        contextvars         pandas              turtledemo
# _datetime           contourpy           parso               types
# _decimal            copy                pathlib             typing
# _distutils_hack     copyreg             pdb                 typing_extensions
# _elementtree        crypt               perfmon             tzdata
# _functools          csv                 pickle              unicodedata
# _hashlib            ctypes              pickletools         unittest
# _heapq              curses              pip                 urllib
# _imp                cycler              pipes               uu
# _io                 dataclasses         pkg_resources       uuid
# _json               datetime            pkgutil             venv
# _locale             dateutil            platform            warnings
# _lsprof             dbi                 platformdirs        wave
# _lzma               dbm                 plistlib            wcwidth
# _markupbase         dde                 poplib              weakref
# _md5                debugpy             posixpath           webbrowser
# _msi                decimal             pprint              win2kras
# _multibytecodec     decorator           profile             win32api
# _multiprocessing    difflib             prompt_toolkit      win32clipboard
# _opcode             dis                 pstats              win32com
# _operator           distutils           psutil              win32con
# _osx_support        doctest             pty                 win32console
# _overlapped         email               pure_eval           win32cred
# _pickle             encodings           py_compile          win32crypt
# _py_abc             ensurepip           pyclbr              win32cryptcon
# _pydecimal          enum                pydoc               win32event
# _pyio               errno               pydoc_data          win32evtlog
# _queue              executing           pyexpat             win32evtlogutil
# _random             faulthandler        pygments            win32file
# _sha1               filecmp             pylab               win32gui
# _sha256             fileinput           pyparsing           win32gui_struct
# _sha3               fnmatch             pythoncom           win32help
# _sha512             fontTools           pytz                win32inet
# _signal             fractions           pywin               win32inetcon
# _sitebuiltins       ftplib              pywin32_bootstrap   win32job
# _socket             functools           pywin32_testutil    win32lz
# _sqlite3            gc                  pywintypes          win32net
# _sre                genericpath         queue               win32netcon
# _ssl                getopt              quopri              win32pdh
# _stat               getpass             random              win32pdhquery
# _statistics         gettext             rasutil             win32pdhutil
# _string             glob                re                  win32pipe
# _strptime           graphlib            regcheck            win32print
# _struct             gzip                regutil             win32process
# _symtable           hashlib             reprlib             win32profile
# _testbuffer         heapq               rlcompleter         win32ras
# _testcapi           hmac                runpy               win32rcparser
# _testconsole        html                sched               win32security
# _testimportmultiple http                secrets             win32service
# _testinternalcapi   idlelib             select              win32serviceutil
# _testmultiphase     imaplib             selectors           win32timezone
# _thread             imghdr              servicemanager      win32trace
# _threading_local    imp                 setuptools          win32traceutil
# _tkinter            importlib           shelve              win32transaction
# _tokenize           inspect             shlex               win32ts
# _tracemalloc        io                  shutil              win32ui
# _typing             ipaddress           signal              win32uiole
# _uuid               ipykernel           site                win32verstamp
# _warnings           ipykernel_launcher  six                 win32wnet
# _weakref            isapi               smtpd               winerror
# _weakrefset         itertools           smtplib             winioctlcon
# _win32sysloader     jedi                sndhdr              winnt
# _winapi             json                socket              winperf
# _winxptheme         jupyter             socketserver        winreg
# _xxsubinterpreters  jupyter_client      sqlite3             winsound
# _zoneinfo           jupyter_core        sre_compile         winxpgui
# abc                 keyword             sre_constants       winxptheme
# adodbapi            kiwisolver          sre_parse           wsgiref
# afxres              lib2to3             ssl                 xdrlib
# aifc                linecache           sspi                xml
# antigravity         locale              sspicon             xmlrpc
# argparse            logging             stack_data          xxsubtype
# array               lzma                start_pythonwin     zipapp
# ast                 mailbox             stat                zipfile
# asttokens           mailcap             statistics          zipimport
# asynchat            marshal             string              zlib
# asyncio             math                stringprep          zmq
# asyncore            matplotlib          struct              zoneinfo
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
