# %% [markdown]
# # Install Common Packages
# Run this notebook to install most common packages to a python kernal.
#
# Start by placing this file in the root of a project.
# If you are using vscode, create a new venv, before starting.
#
# ### Conda env
# if you are using a conda venv, you might get an error message:
#
# "Running cells with '.conda (Python 3.11.9)' requires the ipykernel package....."
#
# then open the terminal (View menu and then select terminal)
# and then run the code suggested code:.
# Remember to add " " around the path to the venv.
#
# 'conda install -p "\<long Path\>\\.conda" ipykernel --update-deps --force-reinstall'

# %%
import sys
path_to_executable = "\"" + str(sys.executable) +  "\""
print(path_to_executable)
# Out:
# "c:\Users\gusta\Documents\GitHub\Arenz_Group_Python\.venv\Scripts\python.exe"

# %%
#req_packages = ["pandas","numpy","nptdms","matplotlib","pathlib"]

# !{path_to_executable} -m pip install numpy
# !{path_to_executable} -m pip install pandas
# !{path_to_executable} -m pip install nptdms
# !{path_to_executable} -m pip install matplotlib
# !{path_to_executable} -m pip install pathlib
# !{path_to_executable} -m pip install scipy
# Out:
# Requirement already satisfied: numpy in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (1.26.3)
# [notice] A new release of pip is available: 23.3.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 1.7 MB/s eta 0:00:07
#    ---------------------------------------- 0.1/11.5 MB 1.4 MB/s eta 0:00:08
#     --------------------------------------- 0.2/11.5 MB 1.5 MB/s eta 0:00:08
#     --------------------------------------- 0.3/11.5 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/11.5 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/11.5 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.5 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/11.5 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.6/11.5 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.7/11.5 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/11.5 MB 1.5 MB/s eta 0:00:08
#    -- ------------------------------------- 0.9/11.5 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 0.9/11.5 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.5 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.5 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.1/11.5 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.2/11.5 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.5 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.5 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.4/11.5 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.5/11.5 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.5/11.5 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.5 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.7/11.5 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.5 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 1.8/11.5 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 1.9/11.5 MB 1.5 MB/s eta 0:00:07
#    ------ --------------------------------- 2.0/11.5 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.0/11.5 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.5 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.2/11.5 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.3/11.5 MB 1.5 MB/s eta 0:00:07
#    -------- ------------------------------- 2.3/11.5 MB 1.5 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.5 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.5/11.5 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/11.5 MB 1.5 MB/s eta 0:00:06
#    --------- ------------------------------ 2.7/11.5 MB 1.5 MB/s eta 0:00:06
#    --------- ------------------------------ 2.7/11.5 MB 1.5 MB/s eta 0:00:06
#    --------- ------------------------------ 2.8/11.5 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.5 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.0/11.5 MB 1.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.1/11.5 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 3.1/11.5 MB 1.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.2/11.5 MB 1.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.3/11.5 MB 1.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.3/11.5 MB 1.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.4/11.5 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 3.5/11.5 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 3.6/11.5 MB 1.5 MB/s eta 0:00:06
#    ------------ --------------------------- 3.6/11.5 MB 1.5 MB/s eta 0:00:06
#    ------------ --------------------------- 3.7/11.5 MB 1.6 MB/s eta 0:00:05
#    ------------- -------------------------- 3.8/11.5 MB 1.5 MB/s eta 0:00:05
#    ------------- -------------------------- 3.9/11.5 MB 1.5 MB/s eta 0:00:05
#    ------------- -------------------------- 3.9/11.5 MB 1.5 MB/s eta 0:00:05
#    ------------- -------------------------- 4.0/11.5 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.1/11.5 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.1/11.5 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 4.2/11.5 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.2/11.5 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 4.3/11.5 MB 1.5 MB/s eta 0:00:05
#    --------------- ------------------------ 4.4/11.5 MB 1.5 MB/s eta 0:00:05
#    --------------- ------------------------ 4.5/11.5 MB 1.5 MB/s eta 0:00:05
#    --------------- ------------------------ 4.5/11.5 MB 1.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.6/11.5 MB 1.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.7/11.5 MB 1.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.8/11.5 MB 1.5 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.8/11.5 MB 1.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.9/11.5 MB 1.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.0/11.5 MB 1.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.1/11.5 MB 1.5 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.1/11.5 MB 1.5 MB/s eta 0:00:05
#    ------------------ --------------------- 5.2/11.5 MB 1.5 MB/s eta 0:00:05
#    ------------------ --------------------- 5.3/11.5 MB 1.5 MB/s eta 0:00:05
#    ------------------ --------------------- 5.4/11.5 MB 1.5 MB/s eta 0:00:04
#    ------------------ --------------------- 5.4/11.5 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 5.5/11.5 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 5.6/11.5 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 5.6/11.5 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 5.7/11.5 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 5.8/11.5 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 5.8/11.5 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 5.8/11.5 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 5.9/11.5 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 6.0/11.5 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 6.0/11.5 MB 1.5 MB/s eta 0:00:04
#    --------------------- ------------------ 6.1/11.5 MB 1.5 MB/s eta 0:00:04
#    --------------------- ------------------ 6.2/11.5 MB 1.5 MB/s eta 0:00:04
#    --------------------- ------------------ 6.3/11.5 MB 1.5 MB/s eta 0:00:04
#    --------------------- ------------------ 6.3/11.5 MB 1.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.4/11.5 MB 1.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.5/11.5 MB 1.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.5/11.5 MB 1.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.6/11.5 MB 1.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.7/11.5 MB 1.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.7/11.5 MB 1.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.8/11.5 MB 1.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.9/11.5 MB 1.5 MB/s eta 0:00:04
#    ------------------------ --------------- 7.0/11.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 7.0/11.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------- -------------- 7.2/11.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------- -------------- 7.3/11.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------- -------------- 7.3/11.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------- -------------- 7.4/11.5 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 7.5/11.5 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 7.6/11.5 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 7.6/11.5 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 7.7/11.5 MB 1.5 MB/s eta 0:00:03
#    --------------------------- ------------ 7.8/11.5 MB 1.5 MB/s eta 0:00:03
#    --------------------------- ------------ 7.9/11.5 MB 1.5 MB/s eta 0:00:03
#    --------------------------- ------------ 7.9/11.5 MB 1.5 MB/s eta 0:00:03
#    --------------------------- ------------ 8.0/11.5 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.1/11.5 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.2/11.5 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.2/11.5 MB 1.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.3/11.5 MB 1.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.4/11.5 MB 1.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.4/11.5 MB 1.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.5/11.5 MB 1.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.6/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.6/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.7/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.8/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.9/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 8.9/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 9.0/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 9.0/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 9.1/11.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 9.2/11.5 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 9.2/11.5 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 9.3/11.5 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.5 MB 1.5 MB/s eta 0:00:02
#    -------------------------------- ------- 9.4/11.5 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.5/11.5 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.6/11.5 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.6/11.5 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 9.7/11.5 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.8/11.5 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.9/11.5 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.9/11.5 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.0/11.5 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.5 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.2/11.5 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.5 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.6/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.8/11.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.9/11.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.4/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 1.5 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    ---- ----------------------------------- 61.4/505.5 kB 1.7 MB/s eta 0:00:01
#    --------- ------------------------------ 122.9/505.5 kB 1.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 204.8/505.5 kB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 266.2/505.5 kB 1.5 MB/s eta 0:00:01
#    --------------------------- ------------ 348.2/505.5 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 430.1/505.5 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  501.8/505.5 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 1.4 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    ---- ----------------------------------- 41.0/345.4 kB 2.0 MB/s eta 0:00:01
#    ------------- -------------------------- 112.6/345.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 194.6/345.4 kB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 276.5/345.4 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  337.9/345.4 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 345.4/345.4 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# [notice] A new release of pip is available: 23.3.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: nptdms in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from nptdms) (1.26.3)
# [notice] A new release of pip is available: 23.3.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.3.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Installing collected packages: pathlib
# Successfully installed pathlib-1.0.1
# [notice] A new release of pip is available: 23.3.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (1.14.0)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\gusta\appdata\local\programs\python\python312\lib\site-packages (from scipy) (1.26.3)
# [notice] A new release of pip is available: 23.3.2 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Check which modules that are installed:

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.43.1
# c:\Users\gusta\AppData\Local\Programs\Python\Python312\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# IPython             binascii            math                stat
# PIL                 bisect              matplotlib          statistics
# __future__          bleach              matplotlib_inline   string
# __hello__           bs4                 mimetypes           stringprep
# __phello__          builtins            mistune             struct
# _abc                bz2                 mmap                subprocess
# _aix_support        cProfile            mmapfile            sunau
# _argon2_cffi_bindings calendar            mmsystem            symtable
# _ast                certifi             modulefinder        sys
# _asyncio            cffi                mpl_toolkits        sysconfig
# _bisect             cgi                 msilib              tabnanny
# _blake2             cgitb               msvcrt              tarfile
# _bz2                charset_normalizer  multiprocessing     telnetlib
# _cffi_backend       chunk               nbclient            tempfile
# _codecs             cmath               nbconvert           terminado
# _codecs_cn          cmd                 nbformat            test
# _codecs_hk          code                nest_asyncio        textwrap
# _codecs_iso2022     codecs              netbios             this
# _codecs_jp          codeop              netrc               threading
# _codecs_kr          collections         nntplib             time
# _codecs_tw          colorama            notebook            timeit
# _collections        colorsys            notebook_shim       timer
# _collections_abc    comm                nptdms              tinycss2
# _compat_pickle      commctrl            nt                  tkinter
# _compression        compileall          ntpath              token
# _contextvars        concurrent          ntsecuritycon       tokenize
# _csv                configparser        nturl2path          tomllib
# _ctypes             contextlib          numbers             tornado
# _ctypes_test        contextvars         numpy               trace
# _datetime           contourpy           odbc                traceback
# _decimal            copy                opcode              tracemalloc
# _elementtree        copyreg             operator            traitlets
# _functools          crypt               optparse            tty
# _hashlib            csv                 os                  turtle
# _heapq              ctypes              overrides           turtledemo
# _imp                curses              packaging           types
# _io                 cycler              pandas              typing
# _json               dataclasses         pandocfilters       tzdata
# _locale             datetime            parso               unicodedata
# _lsprof             dateutil            pathlib             unittest
# _lzma               dbi                 pdb                 uri_template
# _markupbase         dbm                 perfmon             urllib
# _md5                dde                 pickle              urllib3
# _msi                debugpy             pickletools         uu
# _multibytecodec     decimal             pip                 uuid
# _multiprocessing    decorator           pipes               venv
# _opcode             defusedxml          pkgutil             warnings
# _operator           difflib             platform            wave
# _osx_support        dis                 platformdirs        wcwidth
# _overlapped         doctest             plistlib            weakref
# _pickle             email               poplib              webbrowser
# _py_abc             encodings           posixpath           webcolors
# _pydatetime         ensurepip           pprint              webencodings
# _pydecimal          enum                profile             websocket
# _pyio               errno               prometheus_client   win2kras
# _pylong             executing           prompt_toolkit      win32api
# _queue              fastjsonschema      pstats              win32clipboard
# _random             faulthandler        psutil              win32com
# _sha1               filecmp             pty                 win32con
# _sha2               fileinput           pure_eval           win32console
# _sha3               fnmatch             py_compile          win32cred
# _signal             fontTools           py_scripts          win32crypt
# _sitebuiltins       fqdn                pyclbr              win32cryptcon
# _socket             fractions           pycparser           win32event
# _sqlite3            ftplib              pydoc               win32evtlog
# _sre                functools           pydoc_data          win32evtlogutil
# _ssl                gc                  pyexpat             win32file
# _stat               genericpath         pygments            win32gui
# _statistics         getopt              pylab               win32gui_struct
# _string             getpass             pyparsing           win32help
# _strptime           gettext             pythoncom           win32inet
# _struct             glob                pythonjsonlogger    win32inetcon
# _symtable           graphlib            pytz                win32job
# _testbuffer         gzip                pywin               win32lz
# _testcapi           hashlib             pywin32_bootstrap   win32net
# _testclinic         heapq               pywin32_testutil    win32netcon
# _testconsole        hmac                pywintypes          win32pdh
# _testimportmultiple html                queue               win32pdhquery
# _testinternalcapi   http                quopri              win32pdhutil
# _testmultiphase     idlelib             random              win32pipe
# _testsinglephase    idna                rasutil             win32print
# _thread             imaplib             re                  win32process
# _threading_local    imghdr              referencing         win32profile
# _tkinter            importlib           regcheck            win32ras
# _tokenize           inspect             regutil             win32rcparser
# _tracemalloc        io                  reprlib             win32security
# _typing             ipaddress           requests            win32service
# _uuid               ipykernel           rfc3339_validator   win32serviceutil
# _warnings           ipykernel_launcher  rfc3986_validator   win32timezone
# _weakref            isapi               rlcompleter         win32trace
# _weakrefset         isoduration         rpds                win32traceutil
# _win32sysloader     itertools           runpy               win32transaction
# _winapi             jedi                sched               win32ts
# _winxptheme         jinja2              scipy               win32ui
# _wmi                json                secrets             win32uiole
# _xxinterpchannels   json5               select              win32verstamp
# _xxsubinterpreters  jsonpointer         selectors           win32wnet
# _yaml               jsonschema          send2trash          winerror
# _zoneinfo           jsonschema_specifications servicemanager      winioctlcon
# abc                 jupyter             shelve              winnt
# adodbapi            jupyter_client      shlex               winperf
# afxres              jupyter_core        shutil              winpty
# aifc                jupyter_events      signal              winreg
# antigravity         jupyter_lsp         site                winsound
# anyio               jupyter_server      six                 winxpgui
# argon2              jupyter_server_terminals smtplib             winxptheme
# argparse            jupyterlab          sndhdr              wsgiref
# array               jupyterlab_pygments sniffio             xdrlib
# arrow               jupyterlab_server   socket              xml
# ast                 keyword             socketserver        xmlrpc
# asttokens           kiwisolver          soupsieve           xxsubtype
# async_lru           lib2to3             sqlite3             yaml
# asyncio             linecache           sre_compile         zipapp
# atexit              locale              sre_constants       zipfile
# attr                logging             sre_parse           zipimport
# attrs               lzma                ssl                 zlib
# audioop             mailbox             sspi                zmq
# babel               mailcap             sspicon             zoneinfo
# base64              markupsafe          stack_data
# bdb                 marshal             start_pythonwin
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
# !{path_to_executable} -m pip install pooch
# Out:
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\gusta\documents\github\arenz_group_python\.venv\lib\site-packages (from pooch) (4.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\gusta\documents\github\arenz_group_python\.venv\lib\site-packages (from pooch) (24.1)
# Collecting requests>=2.19.0 (from pooch)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch)
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.4 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#    ---------------------------------------- 163.0/163.0 kB 3.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB 1.9 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB 3.5 MB/s eta 0:00:00
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.4 kB ? eta -:--:--
#    ---------------------------------------- 121.4/121.4 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, pooch
# Successfully installed certifi-2024.7.4 charset-normalizer-3.3.2 idna-3.7 pooch-1.8.2 requests-2.32.3 urllib3-2.2.2
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
